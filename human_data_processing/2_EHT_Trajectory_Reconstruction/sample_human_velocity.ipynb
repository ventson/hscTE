# %%
# import packages
import anndata
import scanpy as sc
import scvelo as scv
import pandas as pd
import numpy as np
import matplotlib as plt
# %load_ext rpy2.ipython

import math
import natsort
import pandas
import session_info

# %%
# load loom files
adata1 = scv.read("Aorta-4wk-658.loom", cache = True)
adata2 = scv.read("Aorta-5wk-555.loom", cache = True)
adata3 = scv.read("Aorta-5wk-575.loom", cache = True)
adata1.var_names_make_unique()
adata2.var_names_make_unique()
adata3.var_names_make_unique()

# %%
# load meta info
sample_obs = pd.read_csv("meta/cellID_obs.csv")
cell_clusters = pd.read_csv("meta/clusters.csv", index_col = 0)
umap_cord = pd.read_csv("meta/cell_embeddings.csv")

# %%
# select cells and assign celltype
adata1 = adata1[np.isin(adata1.obs.index, sample_obs["x"])]
adata1.obs['celltype'] = list(cell_clusters.loc[adata1.obs.index, "x"])
adata2 = adata2[np.isin(adata2.obs.index, sample_obs["x"])]
adata2.obs['celltype'] = list(cell_clusters.loc[adata2.obs.index, "x"])
adata3 = adata3[np.isin(adata3.obs.index, sample_obs["x"])]
adata3.obs['celltype'] = list(cell_clusters.loc[adata3.obs.index, "x"])

# %%
# add umap coordinates
umap_cord["UMAP_1"] = umap_cord["UMAP_1"] * -1
umap_cord = umap_cord.rename(columns = {'Unnamed: 0':'CellID'})

adata1_index = pd.DataFrame(adata1.obs.index)
adata2_index = pd.DataFrame(adata2.obs.index)
adata3_index = pd.DataFrame(adata3.obs.index)

umap_ordered_1 = adata1_index.merge(umap_cord, on = "CellID")
umap_ordered_1 = umap_ordered_1.iloc[:,1:]
adata1.obsm['X_umap'] = umap_ordered_1.values

umap_ordered_2 = adata2_index.merge(umap_cord, on = "CellID")
umap_ordered_2 = umap_ordered_2.iloc[:,1:]
adata2.obsm['X_umap'] = umap_ordered_2.values

umap_ordered_3 = adata3_index.merge(umap_cord, on = "CellID")
umap_ordered_3 = umap_ordered_3.iloc[:,1:]
adata3.obsm['X_umap'] = umap_ordered_3.values

# %%
# concatenate 3 samples
adata = adata1.concatenate(adata2, adata3)
adata.obs['clusters'] = adata.obs['celltype']
adata.obs['clusters'] = adata.obs['clusters'].astype('category')
adata.obs['clusters'] = adata.obs['clusters'].cat.set_categories(['VEC','AEC','pre-HEC','HEC','HSC'], ordered=True)
adata_all = adata

# %%
# plot the spliced and unspliced proportion
scv.pl.proportions(adata, figsize=(7, 2), dpi = 300, save="unspliced_proportions.pdf")
# Out:
# saving figure to file ./figures/scvelo_proportions_unspliced_proportions.pdf

# %%
# preprocess the data
scv.pp.filter_genes(adata, min_shared_counts=20)
scv.pp.normalize_per_cell(adata)
scv.pp.filter_genes_dispersion(adata, n_top_genes=2000)
scv.pp.log1p(adata)
# Out:
# Filtered out 27397 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 2000 highly variable genes.

# %%
# filter, normalization and moments
scv.pp.filter_and_normalize(adata, min_shared_counts=20, n_top_genes=2000)
scv.pp.moments(adata, n_pcs=30, n_neighbors=30)
# Out:
# Filtered out 110 genes that are detected 20 counts (shared).
# WARNING: Did not normalize X as it looks processed already. To enforce normalization, set `enforce=True`.
# WARNING: Did not normalize spliced as it looks processed already. To enforce normalization, set `enforce=True`.
# WARNING: Did not normalize unspliced as it looks processed already. To enforce normalization, set `enforce=True`.
# Skip filtering by dispersion since number of variables are less than `n_top_genes`.
# WARNING: Did not modify X as it looks preprocessed already.
# computing neighbors
#     finished (0:00:07) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:01) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)

# %%
# estimate RNA velocity
scv.tl.velocity(adata)
scv.tl.velocity_graph(adata)
# Out:
# computing velocities
#     finished (0:00:01) --> added
#     'velocity', velocity vectors for each individual cell (adata.layers)
# computing velocity graph (using 1/128 cores)
# WARNING: Unable to create progress bar. Consider installing `tqdm` as `pip install tqdm` and `ipywidgets` as `pip install ipywidgets`,
# or disable the progress bar using `show_progress_bar=False`.
#     finished (0:00:10) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)

# %%
# dimension reduction if needed
#scv.tl.umap(adata)
pd.DataFrame(adata.obsm['X_umap'], index=adata.obs.index).to_csv("meta/X_umap.csv")

# %%
# project the velocities
scv.pl.velocity_embedding_stream(adata, basis="umap", color="celltype", save="velocity_human.pdf", dpi=300, figsize=(4,3), linewidth=0.7, arrow_size=0.7, size=40, alpha = 0.5, legend_loc="right margin")
scv.pl.velocity_embedding(adata, color="celltype", arrow_length=3, arrow_size=2, dpi=120)
# Out:
# computing velocity embedding
#     finished (0:00:01) --> added
#     'velocity_umap', embedded velocity vectors (adata.obsm)
# saving figure to file ./figures/scvelo_velocity_human.pdf

# %%
# phase portraits of marker genes
scv.pl.velocity(adata, ['NR2F2', 'GJA5', 'TMEM100', 'MYB'], ncols=2, save="marker_gene_human.pdf")
scv.pl.scatter(adata, 'MYB', color=['celltype', 'velocity'])
# Out:
# saving figure to file ./figures/scvelo_marker_gene_human.pdf

# %%
# plot EPAS1 and GJA5
scv.pl.velocity(adata, ['EPAS1', 'GJA5'], ncols=2)

# %%
# pseudotime
scv.tl.velocity_pseudotime(adata)
scv.pl.scatter(adata, color='velocity_pseudotime', cmap='gnuplot')
# Out:
# computing terminal states
#     identified 1 region of root cells and 2 regions of end points .
#     finished (0:00:00) --> added
#     'root_cells', root cells of Markov diffusion process (adata.obs)
#     'end_points', end points of Markov diffusion process (adata.obs)

# %%
# identify important genes
scv.tl.rank_velocity_genes(adata, groupby='celltype', min_corr=.3)

df = scv.DataFrame(adata.uns['rank_velocity_genes']['names'])
df.head()

kwargs = dict(frameon=False, size=10, linewidth=1.5, add_outline="pre-HEC")

scv.pl.scatter(adata, df['pre-HEC'][:5], ylabel='pre-HEC', color=['celltype'], **kwargs)
scv.pl.scatter(adata, df['HSC'][:5], ylabel='HSC', color=['celltype'], **kwargs)
# Out:
# ranking velocity genes
#     finished (0:00:03) --> added
#     'rank_velocity_genes', sorted scores by group ids (adata.uns)
#     'spearmans_score', spearmans correlation scores (adata.var)
# /tmp/ipykernel_56816/3540916672.py:4: DeprecationWarning: `scvelo.read_load.get_df` is deprecated since scVelo v0.2.4 and will be removed in a future version. Please use `scvelo.core.get_df` instead.
#   df = scv.DataFrame(adata.uns['rank_velocity_genes']['names'])

# %%
# cell cycle scores
scv.tl.score_genes_cell_cycle(adata)
scv.pl.scatter(adata, color_gradients=['S_score', 'G2M_score'], smooth=True, perc=[5, 95], save="cell_cycle.pdf")
# Out:
# calculating cell cycle phase
# -->     'S_score' and 'G2M_score', scores of cell cycle phases (adata.obs)
# saving figure to file ./figures/scvelo_cell_cycle.pdf

# %%
# speed and coherence
scv.tl.velocity_confidence(adata)
keys = 'velocity_length', 'velocity_confidence'
scv.pl.scatter(adata, c=keys, cmap='coolwarm', perc=[5, 95], save="velocity_length.pdf")
# Out:
# --> added 'velocity_length' (adata.obs)
# --> added 'velocity_confidence' (adata.obs)
# --> added 'velocity_confidence_transition' (adata.obs)
# saving figure to file ./figures/scvelo_velocity_length.pdf

# %%
# save the adata
adata.write('sample_human_scvelo.h5ad')

# %%
# plot pre-HEC markers
scv.pl.scatter(adata_all, ['GJA5'], color=['celltype'], dpi=300, figsize=(3.5,3), add_outline="pre-HEC", save="splicing_GJA5_human.pdf")
scv.pl.scatter(adata_all, ['TMEM100'], color=['celltype'], dpi=300, figsize=(3.5,3), add_outline="pre-HEC", save="splicing_TMEM100_human.pdf")
# Out:
# saving figure to file ./figures/scvelo_splicing_GJA5_human.pdf
# saving figure to file ./figures/scvelo_splicing_TMEM100_human.pdf

# %%
# dynamical model
scv.tl.recover_dynamics(adata, n_jobs=10)
# Out:
# recovering dynamics (using 10/128 cores)
#     finished (0:00:59) --> added
#     'fit_pars', fitted parameters for splicing dynamics (adata.var)

# %%
# estimate velocities based on dynamical model
scv.tl.velocity(adata, mode='dynamical')
scv.tl.velocity_graph(adata)
# Out:
# computing velocities
#     finished (0:00:04) --> added
#     'velocity', velocity vectors for each individual cell (adata.layers)
# computing velocity graph (using 1/128 cores)
#     finished (0:00:07) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)

# %%
# save the adata with dynamical model
adata.write('sample_human_dynamical.h5ad')

# %%
# predict latent time
scv.tl.latent_time(adata)
pd.DataFrame(adata.obs.latent_time).to_csv("meta/latent_time_human_EHT.csv")
scv.pl.scatter(adata, color='latent_time', color_map='gnuplot', size=80, save="latent_time.pdf")
# Out:
# computing latent time using root_cells as prior
#     finished (0:00:01) --> added
#     'latent_time', shared time (adata.obs)
# saving figure to file ./figures/scvelo_latent_time.pdf

# %%
# get top variable genes
top_genes = adata.var['fit_likelihood'].sort_values(ascending=False).index
top_genes
# Out:
# Index(['GJA5', 'PALMD', 'PRDM16', 'MYB', 'HEY2', 'IKZF1', 'CD53', 'TOP2A',
#        'SMC4', 'ARHGDIB',
#        ...
#        'TCEAL7', 'INTS6L', 'FHL1', 'MTM1', 'HMGB3', 'BGN', 'DKC1', 'KDM5D',
#        'ZFY', 'PRKY'],
#       dtype='object', name='Gene', length=1890)

# %%
# subset vec cluster
adata_vec = sc.pp.subsample(adata_all[adata_all.obs["celltype"].isin(["VEC"])], n_obs = 300, copy=True)
adata_eht = adata_all[adata_all.obs["celltype"].isin(["AEC", "pre-HEC", "HEC", "HSC"])]
adata_sampled = adata_vec.concatenate(adata_eht)

# %%
# plot heatmaps
#scv.pl.heatmap(adata_sampled, var_names=top_genes, sortby='latent_time', col_color='celltype', n_convolve=100, figsize=(6,6), save="heatmap.pdf")
scv.pl.heatmap(adata_sampled, var_names=top_genes, sortby='latent_time', col_color='celltype', n_convolve=100, figsize=(6,6), save="heatmap.png")
# Out:
# saving figure to file ./figures/scvelo_heatmap_heatmap.png

# %%
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# anndata             0.8.0
# matplotlib          3.5.3
# natsort             8.3.1
# numpy               1.20.3
# pandas              1.3.4
# scanpy              1.9.3
# scvelo              0.2.5
# session_info        1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                         9.4.0
# asttokens                   NA
# backcall                    0.2.0
# beta_ufunc                  NA
# binom_ufunc                 NA
# cffi                        1.15.1
# cloudpickle                 2.2.1
# colorama                    0.4.6
# comm                        0.1.2
# cycler                      0.10.0
# cython_runtime              NA
# dask                        2023.2.0
# dateutil                    2.8.2
# debugpy                     1.6.6
# decorator                   5.1.1
# defusedxml                  0.7.1
# executing                   1.2.0
# fontTools                   4.39.0
# google                      NA
# h5py                        3.8.0
# igraph                      0.10.4
# importlib_metadata          NA
# ipykernel                   6.21.3
# ipython_genutils            0.2.0
# jedi                        0.18.2
# jinja2                      3.0.3
# joblib                      1.1.0
# jupyter_server              1.23.6
# kiwisolver                  1.4.4
# leidenalg                   0.9.1
# llvmlite                    0.36.0
# markupsafe                  2.1.2
# matplotlib_inline           0.1.6
# mpl_toolkits                NA
# nbinom_ufunc                NA
# numba                       0.53.1
# packaging                   23.0
# parso                       0.8.3
# pexpect                     4.8.0
# pickleshare                 0.7.5
# pkg_resources               NA
# platformdirs                3.1.0
# plotly                      5.14.1
# prompt_toolkit              3.0.38
# psutil                      5.9.4
# ptyprocess                  0.7.0
# pure_eval                   0.2.2
# pycparser                   2.21
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.14.0
# pynndescent                 0.5.8
# pyparsing                   3.0.9
# pytz                        2022.7.1
# pytz_deprecation_shim       NA
# rpy2                        3.5.10
# ruamel                      NA
# scipy                       1.7.2
# seaborn                     0.11.2
# setuptools_scm              NA
# six                         1.16.0
# sklearn                     1.0.1
# sphinxcontrib               NA
# stack_data                  0.6.2
# statsmodels                 0.13.1
# tblib                       1.7.0
# texttable                   1.6.7
# threadpoolctl               3.1.0
# tlz                         0.12.0
# toolz                       0.12.0
# tornado                     6.2
# tqdm                        4.62.3
# traitlets                   5.9.0
# typing_extensions           NA
# tzlocal                     NA
# umap                        0.5.2
# wcwidth                     0.2.6
# yaml                        6.0
# zipp                        NA
# zmq                         25.0.0
# zoneinfo                    NA
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.11.0
# jupyter_client      8.0.3
# jupyter_core        5.2.0
# jupyterlab          3.3.4
# notebook            6.5.3
# -----
# Python 3.9.16 | packaged by conda-forge | (main, Feb  1 2023, 21:39:03) [GCC 11.3.0]
# Linux-3.10.0-1160.42.2.el7.x86_64-x86_64-with-glibc2.31
# -----
# Session information updated at 2023-06-14 01:21
# </pre>
# </details>
